# %%
from db import *
from backtest.analyze_factor import *

# %%
params = {
    "prefix": "stock",
    "freq": "M",
    "start": "2012-01-01",
    "end": "2023-01-01",
    "ascending": 1,
    "benchmark_symbol": "000300",
    "scope": "000906",
    "commission_rate": 0.001,
    "slippage_rate": 0.000,
    "n_quantiles":10
    }
analyzer = Analyzer(**params)

# %%
analyzer.set_target_factor('naive_multi_factor', 'multi_factor', calc=True)

# %%
analyzer.indicators
# Out:
#                                 0
# info_ratio                 0.4091
# long_ret                   0.1181
# short_ret                 -0.0454
# long_short_ret             0.1193
# benchmark_ret              0.0487
# long_sharpe                0.6218
# long_calmar                0.6218
# short_sharpe              -0.0159
# short_calmar              -0.0689
# long_short_sharpe          0.6878
# long_short_calmar          0.2869
# short_turnover            12.1379
# long_turnover             13.4994
# win_rate                    0.553
# win_excess_rate            0.5455
# ic_mean                    0.0636
# ic_std                     0.1756
# ic_skew                    0.1119
# ic_kurt                   -0.6776
# icir                       1.2549
# t                           4.162
# ic_gt_0                    0.6212
# max_drawdown               0.3151
# max_drawdown_start     2015-04-30
# max_drawdown_end       2016-01-31
# max_drawdown_duration         276
# ...

# %%
analyzer.plot_all()
